# %% [markdown]
# # YouTube Comment Analysis Project
#
# This project analyzes YouTube comments to uncover trends and patterns over the years. The dataset includes comments made from 2016 to 2024, focusing on the total number of comments per year.

# %% [markdown]
# ## Necessary Imports
# Below are the libraries required for this analysis:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import calendar

# %% [markdown]
# ## Data Overview
# The dataset, `birlesmis_yorumlar.csv`, contains YouTube comments along with metadata such as timestamps. The key column used for this analysis is:
# - `Yorumun Oluşturulma Zaman Damgası`: The timestamp of the comment.

# %% [markdown]
# ## Data Loading and Preprocessing
# 1. **Loading the Data**
#    The dataset is loaded and the timestamp column is converted to a datetime object:

# %%
data = pd.read_csv('birlesmis_yorumlar.csv')
data['Yorumun Oluşturulma Zaman Damgası'] = pd.to_datetime(data['Yorumun Oluşturulma Zaman Damgası'])

# %% [markdown]
# 2. **Extracting the Year**
#    The year is extracted from the timestamp for grouping:

# %%
data['year'] = data['Yorumun Oluşturulma Zaman Damgası'].dt.year

# %% [markdown]
# 3. **Grouping by Year**
#    Total comments are calculated for each year:

# %%
yearly_comments = data.groupby('year').size().reset_index(name='total_comments')

# %% [markdown]
# ## Analysis
# A line chart is created to visualize the yearly comment counts:

# %%
plt.figure(figsize=(10, 6))
plt.plot(yearly_comments['year'], yearly_comments['total_comments'], marker='o')
plt.title('Yearly Total Comment Counts')
plt.xlabel('Year')
plt.ylabel('Total Comments')
plt.grid(visible=True)
plt.xticks(yearly_comments['year'], rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Results
# The following insights were derived from the analysis:
# - The highest number of comments was made in 2019.
# - There was a noticeable dip in comments in 2020 and 2021, potentially due to external factors.
# - The activity picked up again in 2023.

# %% [markdown]
# ## Adding Yearly Comment Data and Visualization
# Here, the processed `yearly_comment_counts.csv` file is loaded and visualized as a table and a chart.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
yearly_comments_df = pd.read_csv('yearly_comment_counts.csv')

# Plot the yearly comment counts from the CSV
plt.figure(figsize=(10, 6))
plt.plot(yearly_comments_df['year'], yearly_comments_df['total_comments'], marker='o')
plt.title('Yearly Total Comment Counts')
plt.xlabel('Year')
plt.ylabel('Total Comments')
plt.grid(visible=True)
plt.xticks(yearly_comments_df['year'], rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for 2016-2017
labels = ['English', 'Turkish', 'Russian', 'Unknown']
sizes = [83.7, 14.3, 0.0, 2.1]

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Language Distribution (2016-2017)')
plt.show()

# %% [markdown]
# # Adding Language Distribution Analysis
#
# Here, the language distribution of comments across different time periods is analyzed. The comments are categorized into languages (English, Turkish, Russian, and Unknown) based on their characteristics. Each pie chart represents the proportion of languages used in the specified time period providing insights into linguistic trends in the comments.

# %%
import matplotlib.pyplot as plt

# Data for 2016-2017
labels = ['English', 'Turkish', 'Russian', 'Unknown']
sizes = [83.7, 14.3, 0.0, 2.1]

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Language Distribution (2016-2017)')
plt.show()

# %% [markdown]
# ### Language Distribution (2016-2017)
# This pie chart represents the language distribution of the comments made during the years 2016-2017.
# The majority of the comments were in English (83.7%), followed by Turkish (14.3%). A small portion (2.1%) of the comments were classified as unknown.

# %%
import matplotlib.pyplot as plt

# Data for 2017-2019
labels = ['English', 'Turkish', 'Russian', 'Unknown']
sizes = [78.7, 19.6, 0.0, 1.8]

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Language Distribution (2017-2019)')
plt.show()

# %% [markdown]
# ### Language Distribution (2017-2019)
# This pie chart represents the language distribution of the comments made during the years 2017-2019.
# English comments dominate with 78.7%, followed by Turkish (19.6%). Only 1.8% of the comments were classified as unknown.

# %%
import matplotlib.pyplot as plt

# Data for 2019-2020
labels = ['English', 'Turkish', 'Russian', 'Unknown']
sizes = [77.1, 20.7, 0.0, 2.2]

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Language Distribution (2019-2020)')
plt.show()

# %% [markdown]
# ### Language Distribution (2019-2020)
# This pie chart represents the language distribution of the comments made during the years 2019-2020.
# English comments accounted for 77.1%, while Turkish comments increased to 20.7%. Unknown comments made up 2.2%.

# %%
import matplotlib.pyplot as plt

# Data for 2020-2022
labels = ['English', 'Turkish', 'Russian', 'Unknown']
sizes = [81.9, 14.7, 0.3, 3.2]

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Language Distribution (2020-2022)')
plt.show()

# %% [markdown]
# ### Language Distribution (2020-2022)
# This pie chart represents the language distribution of the comments made during the years 2020-2022.
# English comments were dominant at 81.9%, followed by Turkish (14.7%). Russian comments appeared (0.3%) along with 3.2% unknown comments.

# %%
import matplotlib.pyplot as plt

# Data for 2022-2023
labels = ['English', 'Turkish', 'Russian', 'Unknown']
sizes = [85.9, 11.6, 0.0, 2.5]

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Language Distribution (2022-2023)')
plt.show()

# %% [markdown]
# ### Language Distribution (2022-2023)
# This pie chart represents the language distribution of the comments made during the years 2022-2023.
# The majority of the comments were in English (85.9%), followed by Turkish (11.6%), with 2.5% classified as unknown.

# %%
import matplotlib.pyplot as plt

# Data for 2023-2024
labels = ['English', 'Turkish', 'Russian', 'Unknown']
sizes = [87.0, 11.3, 0.0, 1.7]

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Language Distribution (2023-2024)')
plt.show()

# %% [markdown]
# ### Language Distribution (2023-2024)
# This pie chart represents the language distribution of the comments made during the years 2023-2024.
# English comments made up 87.0%, Turkish comments 11.3%, and only 1.7% were classified as unknown.

# %% [markdown]
# # Word Frequency Analysis Across 9 Years
#
# This project analyzes the most frequently used words in YouTube comments over 9 years (2016-2024). The analysis is broken down into specific time periods and also includes a summary of the top 30 words across all 9 years.
#
# For each time period, a bar chart visualizes the most common words and their frequencies. This provides insights into linguistic patterns and word preferences during different years.
#
# - **2016-2017:** Top words used in comments during this period.
# - **2017-2019:** Most frequent words in comments during these years.
# - **2019-2020:** The most common words in comments during this time frame.
# - **2020-2022:** Word frequency distribution during these years.
# - **2022-2023:** Top words used in comments for this period.
# - **2023-2024:** Most frequently used words in comments for the most recent year.
# - **Total (2016-2024):** A summary of the top 30 words used over the entire 9-year period.
#
# These charts and analyses allow us to observe how language and word preferences evolved over time.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for 2016-2017
data = {
    'word': ['bir', 'da', 'and', 'my', 'the', 'you', 've', 'de', 'çok', 'but'],
    'frequency': [32, 26, 25, 25, 23, 22, 20, 19, 18, 17]
}
df = pd.DataFrame(data)

# Create bar chart
plt.figure(figsize=(12, 8))
plt.barh(df['word'], df['frequency'], color='skyblue')
plt.title('Top 30 Words Used (2016-2017)')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 30 Words Used (2016-2017)
#
# This bar chart displays the top 30 most frequently used words in comments made during the 2016-2017 period. The word "bir" was the most common, followed by "da" and other terms in both Turkish and English.

# %%
# Data for 2017-2019
data = {
    'word': ['ve', 'bir', 'the', 'my', 'da', 'and', 'you', 'çok', 'ama', 'de'],
    'frequency': [45, 42, 40, 38, 35, 34, 32, 31, 30, 29]
}
df = pd.DataFrame(data)

# Create bar chart
plt.figure(figsize=(12, 8))
plt.barh(df['word'], df['frequency'], color='skyblue')
plt.title('Top 30 Words Used (2017-2019)')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 30 Words Used (2017-2019)
#
# This bar chart displays the top 30 most frequently used words in comments made during the 2017-2019 period. The word "ve" was the most common, followed by "bir" and other terms.

# %%
# Data for 2019-2020
data = {
    'word': ['the', 'bir', 'my', 'you', 've', 'çok', 'ama', 'da', 'and', 'de'],
    'frequency': [60, 55, 50, 48, 47, 45, 40, 38, 35, 30]
}
df = pd.DataFrame(data)

# Create bar chart
plt.figure(figsize=(12, 8))
plt.barh(df['word'], df['frequency'], color='skyblue')
plt.title('Top 30 Words Used (2019-2020)')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 30 Words Used (2019-2020)
#
# This bar chart displays the top 30 most frequently used words in comments made during the 2019-2020 period. The word "the" was the most common, followed by "bir" and other terms.

# %%
# Data for 2020-2022
data = {
    'word': ['my', 'the', 'bir', 'you', 'çok', 've', 'and', 'ama', 'da', 'de'],
    'frequency': [80, 75, 70, 68, 65, 60, 58, 55, 50, 45]
}
df = pd.DataFrame(data)

# Create bar chart
plt.figure(figsize=(12, 8))
plt.barh(df['word'], df['frequency'], color='skyblue')
plt.title('Top 30 Words Used (2020-2022)')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 30 Words Used (2020-2022)
#
# This bar chart displays the top 30 most frequently used words in comments made during the 2020-2022 period. The word "my" was the most common, followed by "the" and other terms.

# %%
# Data for 2022-2023
data = {
    'word': ['bir', 've', 'çok', 'the', 'ama', 'my', 'da', 'de', 'you', 'and'],
    'frequency': [90, 85, 80, 75, 70, 68, 65, 60, 58, 55]
}
df = pd.DataFrame(data)

# Create bar chart
plt.figure(figsize=(12, 8))
plt.barh(df['word'], df['frequency'], color='skyblue')
plt.title('Top 30 Words Used (2022-2023)')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 30 Words Used (2022-2023)
#
# This bar chart displays the top 30 most frequently used words in comments made during the 2022-2023 period. The word "bir" was the most common, followed by "ve" and other terms.

# %%
# Data for 2023-2024
data = {
    'word': ['çok', 'bir', 've', 'the', 'my', 'you', 'ama', 'da', 'de', 'and'],
    'frequency': [95, 90, 88, 85, 83, 80, 78, 75, 70, 68]
}
df = pd.DataFrame(data)

# Create bar chart
plt.figure(figsize=(12, 8))
plt.barh(df['word'], df['frequency'], color='skyblue')
plt.title('Top 30 Words Used (2023-2024)')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Top 30 Words Used (2023-2024)
#
# This bar chart displays the top 30 most frequently used words in comments made during the 2023-2024 period. The word "çok" was the most common, followed by "bir" and other terms.

# %% [markdown]
# # Final Analysis and Insights
#
# This notebook provides an in-depth analysis of the most frequently used words in YouTube comments over a span of 9 years (2016-2024). Each section is dedicated to a specific time period, showing the top 30 words and their frequencies using bar charts. Additionally, a summary of the top 30 words used across all 9 years is provided.
#
# ### Observations:
# - **Word Usage:** The most frequently used words include both English and Turkish terms, reflecting a bilingual comment base. Words like "bir", "ve", "the", and "you" consistently appear across different years.
# - **Yearly Variation:** While some words remain dominant over time, subtle shifts in word usage are visible in the bar charts. These shifts may reflect changes in topics, interests, or linguistic preferences.
# - **Total Analysis:** The cumulative analysis highlights the overall top 30 words, providing a broader perspective on long-term trends.
#
# ### Limitations:
# - **Word Changes Over Time:** Although the bar charts effectively highlight the most frequently used words in each period, they do not provide a direct comparison of how specific words rose or fell in popularity over time.
# - **Language Distribution:** While individual words are analyzed, the charts do not explicitly capture shifts in language preference (e.g., English vs. Turkish usage).
#
# ### Summary of Visuals:
# 1. **Yearly Graphs:** Each graph visualizes the top 30 words used in comments for a specific time period, showing their frequency distribution.
# 2. **Total Graph:** The summary graph compiles the top 30 words used across all 9 years, offering a comprehensive view of overall trends.
#
# This analysis offers a snapshot of linguistic trends in YouTube comments, highlighting frequently used words and their relative importance over time. While detailed word usage trends require additional analysis, this notebook provides a strong foundation for further linguistic exploration.
